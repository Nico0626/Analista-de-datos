# %% [markdown]
# <a href="https://colab.research.google.com/github/Nico0626/Analista-de-datos/blob/main/Documentacion/limpieza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from IPython.display import Markdown, display

sheet_id = '1Qa5X6_s5zTJIFG6y9yaMngnWy01OKwOY'
sheet_name = 'Hoja1'

url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

df = pd.read_csv(url)

df = df.drop(columns=["observaciones"])
df = df.drop(columns=["porcentajeOfertaVirtual"])

print(df)
# Out:
#                          nombreUniversidad   sector     provincia  \
# 0         Universidad Cátolica de la Plata  Privada  Buenos Aires
# 1         Universidad Cátolica de la Plata  Privada  Buenos Aires
# 2         Universidad Cátolica de la Plata  Privada  Buenos Aires
# 3         Universidad Cátolica de la Plata  Privada  Buenos Aires
# 4         Universidad Cátolica de la Plata  Privada  Buenos Aires
# ..                                     ...      ...           ...
# 903  UNIVERSIDAD NACIONAL DE MAR DEL PLATA  Publica  Buenos Aires
# 904  UNIVERSIDAD NACIONAL DE MAR DEL PLATA  Publica  Buenos Aires
# 905  UNIVERSIDAD NACIONAL DE MAR DEL PLATA  Publica  Buenos Aires
# 906  UNIVERSIDAD NACIONAL DE MAR DEL PLATA  Publica  Buenos Aires
# 907  UNIVERSIDAD NACIONAL DE MAR DEL PLATA  Publica  Buenos Aires
#
#                                  nombreCarrera        areaConocimiento  \
# 0            Ciclo de Lic. en Educación Física             Humanidades
# 1    Ciclo de Lic. en Ciencias de la Educación             Humanidades
# 2       Ciclo de Lic. en Filosofía a Distancia             Humanidades
# 3           Ciclo de Profesorado Universitario             Humanidades
# 4                   Ciclo de Lic. en Geografía             Humanidades
# ..                                         ...                     ...
# 903                   Ingeniería en Materiales  Facultad de Ingeniería
# 904                        Ingeniería Mecánica  Facultad de Ingeniería
# 905                         Ingeniería Química  Facultad de Ingeniería
# 906                         Lic. en Psicología  Facultad de Psicología
# 907                                   Medicina    FACULTAD DE MEDICINA
#
#                     nivel   modalidad duracionAnios cantidadCarrerasVirtuales  \
# 0    Grado complementario   Distancia           1,5                        19
# 1    Grado complementario   Distancia             2                        19
# 2    Grado complementario   Distancia             2                        19
# 3    Grado complementario   Distancia           1,5                        19
# 4    Grado complementario   Distancia             2                        19
# ..                    ...         ...           ...                       ...
# 903      Carrera de Grado  PRESENCIAL             5                         0
# 904      Carrera de Grado  PRESENCIAL             5                         0
# 905      Carrera de Grado  PRESENCIAL             5                         0
# 906      Carrera de Grado  PRESENCIAL             5                         0
# 907      Carrera de Grado  PRESENCIAL             6                         0
#
#      cantidadAreas  ... Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 0              4.0  ...         NaN         NaN         NaN         NaN
# 1              4.0  ...         NaN         NaN         NaN         NaN
# 2              4.0  ...         NaN         NaN         NaN         NaN
# 3              4.0  ...         NaN         NaN         NaN         NaN
# 4              4.0  ...         NaN         NaN         NaN         NaN
# ..             ...  ...         ...         ...         ...         ...
# 903           10.0  ...         NaN         NaN         NaN         NaN
# 904           10.0  ...         NaN         NaN         NaN         NaN
# 905           10.0  ...         NaN         NaN         NaN         NaN
# 906           10.0  ...         NaN         NaN         NaN         NaN
# 907           10.0  ...         NaN         NaN         NaN         NaN
#
#      Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 903          NaN          NaN          NaN          NaN          NaN
# 904          NaN          NaN          NaN          NaN          NaN
# 905          NaN          NaN          NaN          NaN          NaN
# 906          NaN          NaN          NaN          NaN          NaN
# 907          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 25
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 903          NaN
# 904          NaN
# 905          NaN
# 906          NaN
# 907          NaN
#
# [908 rows x 26 columns]
#                          nombreUniversidad   sector     provincia  \
# 0         Universidad Cátolica de la Plata  Privada  Buenos Aires
# 1         Universidad Cátolica de la Plata  Privada  Buenos Aires
# 2         Universidad Cátolica de la Plata  Privada  Buenos Aires
# 3         Universidad Cátolica de la Plata  Privada  Buenos Aires
# 4         Universidad Cátolica de la Plata  Privada  Buenos Aires
# ..                                     ...      ...           ...
# 903  UNIVERSIDAD NACIONAL DE MAR DEL PLATA  Publica  Buenos Aires
# 904  UNIVERSIDAD NACIONAL DE MAR DEL PLATA  Publica  Buenos Aires
# 905  UNIVERSIDAD NACIONAL DE MAR DEL PLATA  Publica  Buenos Aires
# 906  UNIVERSIDAD NACIONAL DE MAR DEL PLATA  Publica  Buenos Aires
# 907  UNIVERSIDAD NACIONAL DE MAR DEL PLATA  Publica  Buenos Aires
#
#                                  nombreCarrera        areaConocimiento  \
# 0            Ciclo de Lic. en Educación Física             Humanidades
# 1    Ciclo de Lic. en Ciencias de la Educación             Humanidades
# 2       Ciclo de Lic. en Filosofía a Distancia             Humanidades
# 3           Ciclo de Profesorado Universitario             Humanidades
# 4                   Ciclo de Lic. en Geografía             Humanidades
# ..                                         ...                     ...
# 903                   Ingeniería en Materiales  Facultad de Ingeniería
# 904                        Ingeniería Mecánica  Facultad de Ingeniería
# 905                         Ingeniería Química  Facultad de Ingeniería
# 906                         Lic. en Psicología  Facultad de Psicología
# 907                                   Medicina    FACULTAD DE MEDICINA
#
#                     nivel   modalidad duracionAnios cantidadCarrerasVirtuales  \
# 0    Grado complementario   Distancia           1,5                        19
# 1    Grado complementario   Distancia             2                        19
# 2    Grado complementario   Distancia             2                        19
# 3    Grado complementario   Distancia           1,5                        19
# 4    Grado complementario   Distancia             2                        19
# ..                    ...         ...           ...                       ...
# 903      Carrera de Grado  PRESENCIAL             5                         0
# 904      Carrera de Grado  PRESENCIAL             5                         0
# 905      Carrera de Grado  PRESENCIAL             5                         0
# 906      Carrera de Grado  PRESENCIAL             5                         0
# 907      Carrera de Grado  PRESENCIAL             6                         0
#
#      cantidadAreas  ... Unnamed: 16 Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# 0              4.0  ...         NaN         NaN          NaN          NaN
# 1              4.0  ...         NaN         NaN          NaN          NaN
# 2              4.0  ...         NaN         NaN          NaN          NaN
# 3              4.0  ...         NaN         NaN          NaN          NaN
# 4              4.0  ...         NaN         NaN          NaN          NaN
# ..             ...  ...         ...         ...          ...          ...
# 903           10.0  ...         NaN         NaN          NaN          NaN
# 904           10.0  ...         NaN         NaN          NaN          NaN
# 905           10.0  ...         NaN         NaN          NaN          NaN
# 906           10.0  ...         NaN         NaN          NaN          NaN
# 907           10.0  ...         NaN         NaN          NaN          NaN
#
#      Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 903          NaN          NaN          NaN          NaN          NaN
# 904          NaN          NaN          NaN          NaN          NaN
# 905          NaN          NaN          NaN          NaN          NaN
# 906          NaN          NaN          NaN          NaN          NaN
# 907          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 25
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 903          NaN
# 904          NaN
# 905          NaN
# 906          NaN
# 907          NaN
#
# [908 rows x 24 columns]
